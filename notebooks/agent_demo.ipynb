# %% [markdown]
# # Agent Demo (Auto Notebook)
# Run the guided SecureBank agent flow without using the CLI.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), 'src'))

import asyncio
from banking_agent.main import demo_scenario

asyncio.run(demo_scenario())
