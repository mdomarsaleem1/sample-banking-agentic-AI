# %% [markdown]
# # API Layer Demo
# Showcase the mock banking APIs that the agent calls.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), 'src'))

import asyncio
from run_api_demo import demonstrate_apis

asyncio.run(demonstrate_apis())
